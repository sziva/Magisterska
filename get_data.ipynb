# %%
import pandas as pd

# %%
data=pd.read_csv("dataGSE39791.csv")
data=data[data.columns[1:]]
p_data=pd.read_csv("pDataGSE39791.csv")

# %%
data2 = data.rename(columns=dict(zip(p_data["geo_accession"],p_data["title"])))
data2.to_csv("dataGSE39791_2.csv", index=False)

# %%
# Out:
#             Symbol  GSM979051  GSM979052  GSM979053  GSM979054  GSM979055  \
# 0           EEF1A1      14.67      14.33      14.27      14.72      14.13
# 1            GAPDH      10.65      11.10       9.90      11.08      11.21
# 2        LOC643334       6.63       6.89       6.51       6.69       6.41
# 3          SLC35E2       6.74       6.81       6.71       6.94       6.46
# 4           DUSP22       6.52       6.67       6.85       6.68       6.63
# 5        LOC642820       6.87       6.83       6.75       6.73       6.81
# 6            RPS28      13.53      12.61      13.09      13.29      13.64
# 7            IPO13       8.07       8.18       7.32       7.45       7.57
# 8           TESSP1       6.63       6.63       6.61       6.72       6.64
# 9        LOC653113       6.51       6.77       6.86       6.79       6.80
# 10           AFAP1       6.62       6.56       6.63       6.49       6.64
# 11          GGTLC1       6.49       6.58       6.52       6.52       6.56
# ...
